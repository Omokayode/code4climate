# %% [markdown]
# <a href="https://colab.research.google.com/drive/1aSy8N-8kM4HQdXqPW8WJBvXZgvLWcqsd" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get today's Notebook at: www.eng.mu.edu/ccl/c4c
#
# ---
# # Tuesday: Is the air safe out there now?
#
# This project will let you practice
# *   Lists, loops, and conditional statements
# *   Functions, and
# *   Basic Python structure
#
# ---
# ## Make a copy of this Notebook
#
# - Go to `File > Save a copy in Drive`
#   - You may want to change the default name to `your-name-Tuesday-project.ipynb`
# - Now, follow the instructions and start coding!

# %% [markdown]
# ---
# # Let's talk about Air Quality Index

# %% [markdown]
# ---
# ## Tuesday: Analyzing a Series of Readings
# Concept Focus: Lists, Loops, Conditional Statements, Functions
#
# First create a function that takes AQI number as input and classifies the AQI as "Good", "Moderate", "Unhealthy for Sensitive Groups", etc. based on simplified Environmental Protection Agencey (EPA) standards.
#
# | AQI Range | Air Quality |
# |-----------|-------------|
# | 0-50 | Good |
# | 51-100 | Moderate |
# | 101-150 | Unhealthy for Sensitive Groups |
# | 151-200 | Unhealthy |
# | 201-300 | Very Unhealthy |
# | 301+ | Hazardous |
#
# Let's imagine on a single day, the following AQI readings were measured for every hour (starting with midnight, i.e., 12 am):
# ```python
# AQI = [45, 55, 75, 95, 105, 115, 135, 155, 175, 205, 255, 305, 350, 400, 450, 500, 45, 55, 75, 95, 105, 115, 135, 155, 175]
# ```
#
# Write a program that uses the above function to loop over the hours of the day and print out a warning when the air is not good outside.

# %%
# Tuesday: Define a function to classify air quality
def classify_aqi(aqi):
    if 0 <= aqi <= 50:
        return "Good"
    elif 51 <= aqi <= 100:
        return "Moderate"
    elif 101 <= aqi <= 150:
        return "Unhealthy for Sensitive Groups"
    elif 151 <= aqi <= 200:
        return "Unhealthy"
    elif 201 <= aqi <= 300:
        return "Very Unhealthy"
    else:
        return "Hazardous"
